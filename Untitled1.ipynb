# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4", input_shape=IMAGE_SHAPE+(3,))
])

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %%
Image.open('goldfish.webp')
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=930x590>

# %%
gold_fish=Image.open('goldfish.webp').resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
np.array(gold_fish)
# Out:
# array([[[ 78,  74,  85],
#         [ 77,  73,  84],
#         [ 76,  72,  85],
#         ...,
#         [ 65,  61,  54],
#         [ 65,  62,  56],
#         [ 65,  61,  55]],
#
#        [[ 77,  73,  83],
#         [ 75,  71,  82],
#         [ 77,  72,  85],
#         ...,
#         [ 65,  62,  55],
#         [ 66,  63,  57],
#         [ 63,  60,  53]],
#
#        [[ 81,  77,  87],
#         [ 79,  75,  86],
#         [ 79,  75,  87],
#         ...,
#         [ 65,  62,  55],
#         [ 66,  63,  57],
#         [ 66,  63,  56]],
#
#        ...,
#
#        [[ 81, 120,  97],
#         [ 81, 120,  97],
#         [ 87, 139, 100],
#         ...,
#         [ 69,  82,  75],
#         [ 73,  86,  75],
#         [ 72,  84,  71]],
#
#        [[ 83, 122,  96],
#         [ 81, 120,  93],
#         [ 81, 126,  92],
#         ...,
#         [ 72,  85,  72],
#         [ 73,  85,  72],
#         [ 71,  84,  72]],
#
#        [[ 84, 123,  95],
#         [ 80, 120,  92],
#         [ 77, 120,  89],
#         ...,
#         [ 70,  84,  72],
#         [ 71,  84,  72],
#         [ 73,  86,  75]]], dtype=uint8)

# %%
gold_fish=np.array(gold_fish)/255
gold_fish
# Out:
# array([[[0.30588235, 0.29019608, 0.33333333],
#         [0.30196078, 0.28627451, 0.32941176],
#         [0.29803922, 0.28235294, 0.33333333],
#         ...,
#         [0.25490196, 0.23921569, 0.21176471],
#         [0.25490196, 0.24313725, 0.21960784],
#         [0.25490196, 0.23921569, 0.21568627]],
#
#        [[0.30196078, 0.28627451, 0.3254902 ],
#         [0.29411765, 0.27843137, 0.32156863],
#         [0.30196078, 0.28235294, 0.33333333],
#         ...,
#         [0.25490196, 0.24313725, 0.21568627],
#         [0.25882353, 0.24705882, 0.22352941],
#         [0.24705882, 0.23529412, 0.20784314]],
#
#        [[0.31764706, 0.30196078, 0.34117647],
#         [0.30980392, 0.29411765, 0.3372549 ],
#         [0.30980392, 0.29411765, 0.34117647],
#         ...,
#         [0.25490196, 0.24313725, 0.21568627],
#         [0.25882353, 0.24705882, 0.22352941],
#         [0.25882353, 0.24705882, 0.21960784]],
#
#        ...,
#
#        [[0.31764706, 0.47058824, 0.38039216],
#         [0.31764706, 0.47058824, 0.38039216],
#         [0.34117647, 0.54509804, 0.39215686],
#         ...,
#         [0.27058824, 0.32156863, 0.29411765],
#         [0.28627451, 0.3372549 , 0.29411765],
#         [0.28235294, 0.32941176, 0.27843137]],
#
#        [[0.3254902 , 0.47843137, 0.37647059],
#         [0.31764706, 0.47058824, 0.36470588],
#         [0.31764706, 0.49411765, 0.36078431],
#         ...,
#         [0.28235294, 0.33333333, 0.28235294],
#         [0.28627451, 0.33333333, 0.28235294],
#         [0.27843137, 0.32941176, 0.28235294]],
#
#        [[0.32941176, 0.48235294, 0.37254902],
#         [0.31372549, 0.47058824, 0.36078431],
#         [0.30196078, 0.47058824, 0.34901961],
#         ...,
#         [0.2745098 , 0.32941176, 0.28235294],
#         [0.27843137, 0.32941176, 0.28235294],
#         [0.28627451, 0.3372549 , 0.29411765]]])

# %%
gold_fish.shape
# Out:
# (224, 224, 3)

# %%
gold_fish[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
classifier.predict(gold_fish[np.newaxis,...])
# Out:
# 1/1 [==============================] - 0s 129ms/step
# array([[ 0.20644122,  3.4081442 , 10.502601  , ..., -1.5236137 ,
#          0.6053841 ,  0.6345376 ]], dtype=float32)

# %%
 result=classifier.predict(gold_fish[np.newaxis,...])
result.shape
# Out:
# 1/1 [==============================] - 0s 120ms/step
# (1, 1001)

# %%
np.argmax(result)
# Out:
# 2
